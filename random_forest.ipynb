# %%
import pandas as pd
from os import path
from sklearn.ensemble import RandomForestClassifier

# %%
filename = path.join(".", "data", "exoplanet_data.csv")

df = pd.read_csv(filename)
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
target = df["koi_disposition"]
target_names = ["negative", "positive"]

# %%
data = df.drop("koi_disposition", axis=1)
feature_names = data.columns
data.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %%
# Split the data into train/test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=12)

# %%
# Scale the data
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
rf = RandomForestClassifier(n_estimators=2000)
rf = rf.fit(X_train, y_train)
rf.score(X_train, y_train)
# Out:
# 1.0

# %%
importances = rf.feature_importances_
importances
# Out:
# array([0.09630779, 0.06793284, 0.10729492, 0.03379916, 0.022429  ,
#        0.01761031, 0.0171555 , 0.01286185, 0.0222789 , 0.02223984,
#        0.0180853 , 0.01121017, 0.0106297 , 0.02269693, 0.03386755,
#        0.03422798, 0.01975669, 0.01427997, 0.01388791, 0.04905514,
#        0.03289141, 0.03443373, 0.01571659, 0.01592902, 0.01833015,
#        0.01603208, 0.05774062, 0.00317103, 0.00911008, 0.02940378,
#        0.02567803, 0.00929894, 0.00863091, 0.01044698, 0.00953741,
#        0.01217405, 0.00901645, 0.01229574, 0.01156764, 0.01098794])

# %%
sorted(zip(importances, feature_names), reverse=True)
# Out:
# [(0.10729492115119435, 'koi_fpflag_co'),
#  (0.09630779426808275, 'koi_fpflag_nt'),
#  (0.0679328400272922, 'koi_fpflag_ss'),
#  (0.05774062434679921, 'koi_model_snr'),
#  (0.04905513642944998, 'koi_prad'),
#  (0.03443373496167371, 'koi_prad_err2'),
#  (0.03422798190436958, 'koi_duration_err2'),
#  (0.0338675494454625, 'koi_duration_err1'),
#  (0.033799157018892995, 'koi_fpflag_ec'),
#  (0.032891414293271234, 'koi_prad_err1'),
#  (0.0294037784624116, 'koi_steff_err1'),
#  (0.025678029383394026, 'koi_steff_err2'),
#  (0.02269692711755939, 'koi_duration'),
#  (0.02242899530808955, 'koi_period'),
#  (0.02227889775259602, 'koi_time0bk_err1'),
#  (0.02223984013556881, 'koi_time0bk_err2'),
#  (0.01975668707726609, 'koi_depth'),
#  (0.01833014606156796, 'koi_insol_err1'),
#  (0.018085302652092433, 'koi_impact'),
#  (0.01761031207352767, 'koi_period_err1'),
#  (0.01715549864021435, 'koi_period_err2'),
#  (0.016032078749301563, 'koi_insol_err2'),
#  (0.01592901624007427, 'koi_insol'),
#  (0.01571658842055422, 'koi_teq'),
#  (0.014279968490160465, 'koi_depth_err1'),
#  (0.013887907376282744, 'koi_depth_err2'),
#  (0.012861845131896102, 'koi_time0bk'),
#  (0.012295741571012738, 'ra'),
#  (0.012174045209473084, 'koi_srad_err1'),
#  (0.011567637009583664, 'dec'),
#  (0.011210173179656035, 'koi_impact_err1'),
#  (0.01098793752952747, 'koi_kepmag'),
#  (0.010629704867735493, 'koi_impact_err2'),
#  (0.010446975615592624, 'koi_slogg_err2'),
#  (0.009537405295538984, 'koi_srad'),
#  (0.009298940645074218, 'koi_slogg'),
#  (0.009110081583904663, 'koi_steff'),
#  (0.009016451527469164, 'koi_srad_err2'),
#  (0.008630907392614564, 'koi_slogg_err1'),
#  (0.0031710256537715907, 'koi_tce_plnt_num')]
